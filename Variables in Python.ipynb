# %%
2+3
# Out:
# 5

# %%
x=2
y=3
z=x+y

# %%
z
# Out:
# 5

# %%
type(x)
# Out:
# int

# %%
x=3.562481
z=x+y

# %%
z
# Out:
# 6.562481

# %%
type(x)
# Out:
# float

# %%
name="sankalp"
name
# Out:
# 'sankalp'

# %%
fullname= name + " lakhera"

# %%
fullname
# Out:
# 'sankalp lakhera'

# %%
val=True
type(val)
# Out:
# bool

# %%
complexNum= 7+2j
type(complexNum)
# Out:
# complex

# %%
complexNum.real
# Out:
# 7.0

# %%
val1=True
val2=False
val1-val2
# Out:
# 1
