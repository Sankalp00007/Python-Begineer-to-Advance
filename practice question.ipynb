# %%
palindromic_check= str(input("Enter the word to check:"))
if palindromic_check == palindromic_check[::-1]:
  print("the string is palindromic")
else:
  print("the string is not a palindromic string")
# Out:
# Enter the word to check:dad
# the string is palindromic

# %% [markdown]
# **to check wheather the chracter entered by the user is a vowel or consonent**

# %%
vowel_list = ('a','e','i','o','u')
character_check= str(input("enter the character to be checked:"))

if character_check in vowel_list:
  print("the given chracter is a vowel")
else:
  print("the character is a consonent")
# Out:
# enter the character to be checked:j
# the character is a consonent
