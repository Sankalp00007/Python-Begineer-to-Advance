# %%
str1="priya"

# %%
type(str1)
# Out:
# str

# %%
str1[3]
# Out:
# 'y'

# %%
## inbuilt function
##find - search a character in the string

str1.find('a')
# Out:
# 4

# %%
## if the character is not present in the string
str1.find('z')
# Out:
# -1

# %%
## split function
## also helps in NLP
##sentiment analysis
text= "hello priya"
text.split()
# Out:
# ['hello', 'priya']

# %%
## replace the word priya to python
## do reassignment to get the new replaced value
text= text.replace('priya','python')

# %%
text
# Out:
# 'hello python'

# %%
## count function- count the given  characters
str2="priya bhatia"
## how many times character 'a' appears in the str2
str2.count('a')
# Out:
# 3

# %%
## slicing
str1="priya"
str1[0:3]
# Out:
# 'pri'

# %%
str1[0:5:2]
# Out:
# 'pia'

# %%
str1[::2]
# Out:
# 'pia'

# %%
##reversing the string
str1[4::-1]
# Out:
# 'ayirp'

# %%
str1[4:1:-1]
# Out:
# 'ayi'
