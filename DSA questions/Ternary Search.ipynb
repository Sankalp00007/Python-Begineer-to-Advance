# %%
def TernarySearch(arr,i,j,key):
    while i<=j:
        mid1= i+(j-i)//3
        mid2= j-(j-i)//3
        if arr[mid1]== key:
            return mid1
        elif arr[mid2]== key:
            return mid2
        elif key < arr[mid1]:
            return TernarySearch(arr,i,mid1-1,key)
        elif key > arr[mid2]:
            return TernarySearch(arr,mid2+1,j,key)
        else:
            return TernarySearch(arr,mid1+1,mid2-1,key)
    return -1

## driver code
arr=[20,25,47,56,59,63,65,79,82]
i=0
j= len(arr)-1
key = 79

result = TernarySearch(arr,i,j,key)
print("the key is at index:",result)
# Out:
# the key is at index: 7

# %% [markdown]
# Using Iterative

# %%
def TernarySearch(arr,i,j,key):
    while i<=j:
        mid1= i+(j-i)//3
        mid2= j-(j-i)//3
        if arr[mid1]== key:
            return mid1
        elif arr[mid2]== key:
            return mid2
        elif key < arr[mid1]:
            j=mid1-1
        elif key > arr[mid2]:
            i=mid2+1
        else:
            i=mid1+1
            j=mid2-1
    return -1

## driver code
arr=[20,25,47,56,59,63,65,79,82]
i=0
j= len(arr)-1
key = 79

result = TernarySearch(arr,i,j,key)
print("the key is at index:",result)
# Out:
# the key is at index: 7
