# %%
## binary search algorithm
def binarySearch(arr,x,i,j):
    while i<=j:
        mid= i + (j-i)//2
        if arr[mid]==x:
            return mid
        elif arr[mid] < x :
            ## right side
            ## from mid+1 to j
            return binarySearch(arr,x,mid+1,j)
        else:
            ## left side
            ## from i to mid-1
            return binarySearch(arr,x,i,mid-1)
     ## element is not present in the array       
    return -1       

## Driver code
arr=[20,30,40,50,60,80,90]
x= 60
i=0
j= len(arr)-1
## function calling
result= binarySearch(arr,x,i,j)
print("Searching element is present at index:",result)
# Out:
# Searching element is present at index: 4

# %% [markdown]
# SAME CODE BUT ITERATIVE APPROACH

# %%
## binary search algorithm
def binarySearch(arr,x,i,j):
    while i<=j:
        mid= i + (j-i)//2
        if arr[mid]==x:
            return mid
        elif arr[mid] < x :
            ## right side
            ## from mid+1 to j
            i= mid+1
        else:
            ## left side
            ## from i to mid-1
            j= mid-1
     ## element is not present in the array       
    return -1       

## Driver code
arr=[20,30,40,50,60,80,90]
x= 60
i=0
j= len(arr)-1
## function calling
result= binarySearch(arr,x,i,j)
print("Searching element is present at index:",result)
# Out:
# Searching element is present at index: 4
