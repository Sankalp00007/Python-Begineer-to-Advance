# %%
## method implementation
def Selectionsort(arr):
    n= len(arr)
    for i in range (n):
        min_idx = i
        for j in range(i+1,n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i],arr[min_idx] = arr[min_idx] , arr[i]
    return arr

## driver code
arr=[70,56,23,19,25,37,48]
result= Selectionsort(arr)
print("sorted array after applying selection sort is:",result)
# Out:
# sorted array after applying selection sort is: [19, 23, 25, 37, 48, 56, 70]
