# %%
iit_shortlist_percentage=90.0
candidate_percentage= float(input("enter your percentage:"))
if candidate_percentage>= iit_shortlist_percentage:
  print("congratulations you are selected.")
else:
  print("sorry,may try for next time")
# Out:
# enter your percentage:94
# congratulations you are selected.

# %% [markdown]
# **Movie ticket pricing **

# %%
age= int(input("enter your age:"))
day= input("its a weekday or weekend ").lower()

if age<5:
 price=0
elif age<=12:
 price=100
elif age>=65:
 price=80
else:
  price=200

## apply surplus charge for weekend

if day== "weekend":
  price+= 150

print("Movie ticket price: ",price,"INR")
# Out:
# enter your age:20
# its a weekday or weekend weekend
# Movie ticket price:  350 INR
